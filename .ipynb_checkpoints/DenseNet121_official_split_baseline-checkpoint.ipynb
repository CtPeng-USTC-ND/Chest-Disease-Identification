# %% [markdown]
# # 测试DenseNet

# %%
import os
import numpy as np
import pandas as pd
from scipy import misc
os.environ["CUDA_VISIBLE_DEVICES"] = "4"

# %%
root_path = '/data1/pengchengtao/Chest X-ray disease'

test_list = pd.read_table(os.path.join(root_path, 'csv/test_list.txt'), header=None)
train_val_list = pd.read_table(os.path.join(root_path, 'csv/train_val_list.txt'), header=None)

df = pd.read_csv(os.path.join(root_path, 'csv/labels_v14_v2.csv'))
bbox = pd.read_csv(os.path.join(root_path, 'csv/bbox_labels.csv'))

from sklearn.cross_validation import train_test_split

X_val, y_val = df[df['Image Index'].isin(test_list[0])]['Image Index'].values, df[df['Image Index'].isin(test_list[0])].iloc[:, 5:].values

X_train_df = df[df['Image Index'].isin(train_val_list[0])]
X_train, _, y_train, _ = train_test_split(X_train_df['Patient ID'].unique(), X_train_df['Patient ID'].unique(), test_size=0.125, random_state=666)
X_train, y_train = df[df['Patient ID'].isin(X_train)]['Image Index'].values, df[df['Patient ID'].isin(X_train)].iloc[:, 5:].values
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def to_np(x):
    return x.data.cpu().numpy()

def to_var(x, is_volatile=False):
    if torch.cuda.is_available():
        x = x.cuda()
    if is_volatile:
        return Variable(x, volatile=True)
    else:
        return Variable(x)

# %%
from keras.preprocessing.image import ImageDataGenerator

import cv2, random
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import Dataset

def set_generator():
    data_gen_args = dict(featurewise_center=False,
                    featurewise_std_normalization=False,
                    rotation_range=20.,
                    fill_mode='constant',
                    cval=0.,
                    width_shift_range=0.1,
                    height_shift_range=0.1,
                    zoom_range=0.2,
                    horizontal_flip=True,
                    vertical_flip=False,
                    data_format='channels_first')
    return ImageDataGenerator(**data_gen_args)

class ChestDataset(Dataset):
    def __init__(self, root_path, file_list, label_list, bbox_list, phase=None):
        self.root_path = root_path
        self.phase, self.file_list, self.label_list, self.bbox_list = phase, file_list, label_list, bbox_list
        
        self.datagen = set_generator()
        self.mean = [0.485, 0.456, 0.406]
        self.std = [0.229, 0.224, 0.225]
        
    def __getitem__(self, index):
        seed = random.randint(1, 100000)
        img = self.normalize_data(os.path.join(self.root_path, self.file_list[index]))
        if self.phase == 'train':
            for img_data in self.datagen.flow(img[np.newaxis, ...], batch_size=1, seed=seed): break
            img = img_data[0, ...]
        
        label = self.label_list[index]
        return img.astype(np.float32), label, [0, 0]#, [mask_label, flag]
    
    def normalize_data(self, path):
        data = cv2.imread(path)
        data = cv2.resize(data, (224, 224)) / 255.
        data = (data - self.mean) / self.std
        return data.transpose(2, 0, 1)
    
    def __len__(self):
        return len(self.file_list)
# Out:
# Using TensorFlow backend.

# %%
class DenseNetChest(nn.Module):
    def __init__(self, pretrained_model, num_classes=14):
        super(DenseNetChest, self).__init__()
        self.features = list(densenet.children())[0]
        self.classifier = nn.Linear(1024, num_classes).cuda()
    
    def forward(self, x):
        features = self.features(x)
        out = F.relu(features, inplace=True)
        out = F.avg_pool2d(out, kernel_size=7, stride=1).view(features.size(0), -1)
        out = self.classifier(out)
        out = F.sigmoid(out)
        return out

# %%
import torchvision.models as models
densenet = models.densenet121(pretrained=True).cuda()
net = DenseNetChest(densenet)

# %%
num_epochs = 50
batch_size = 24
num_workers = 8
root_path = '/data1/pengchengtao/Chest X-ray disease/Chest_x_ray8/images/'

trainset = ChestDataset(root_path=root_path, file_list=X_train, label_list=y_train, 
                        bbox_list=bbox[bbox['Image Index'].isin(X_train)]['Image Index'].values, phase='train')

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=num_workers)

valset = ChestDataset(root_path=root_path, file_list=X_val, label_list=y_val,
                     bbox_list=bbox[bbox['Image Index'].isin(X_val)]['Image Index'].values, phase='val')
valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size, shuffle=False, num_workers=num_workers)

# testset = ChestDataset(root_path=root_path, file_list=X_test, label_list=y_test,
#                       bbox_list=bbox[bbox['Image Index'].isin(X_test)]['Image Index'].values, phase='test')
# testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=num_workers)

# %%
from torch import optim
from torch.optim.lr_scheduler import *
if torch.cuda.is_available():
    net.cuda()
criterion = nn.BCELoss().cuda()
learning_rate = 0.0001
optimizer = optim.Adam (net.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=1e-5)
scheduler = ReduceLROnPlateau(optimizer, factor = 0.1, patience = 5, mode = 'min')
# scheduler = MultiStepLR(optimizer, milestones=[30,50,80], gamma=0.1)

# %%
from sklearn.metrics import roc_auc_score
col_name = df.columns[-14:]

# %%
def eval(net, valloader, step):
    net.eval()
    total_loss = 0.0
    gt, predict = [], []
    for i, data in enumerate(valloader, 0):
        inputs, labels, _ = data
        inputs, labels = to_var(inputs, is_volatile=True), to_var(labels, is_volatile=True)

        outputs = net(inputs)

        loss = criterion(outputs.view(-1, 1), Variable(labels.data.type(torch.FloatTensor)).cuda().view(-1, 1))

        total_loss += loss.data[0]

        predict.append(outputs.cpu().data.numpy())
        gt.append(labels.cpu().data.numpy())

    gt = np.concatenate(gt, 0)
    predict = np.concatenate(predict, 0) 
    print 'Total val loss:{}'.format(total_loss / (i+1))
    roc_array = []
    for j, name in enumerate(col_name):
        roc_array.append(roc_auc_score(gt[:, j], predict[:, j]))
        print 'AUC: {}:{}'.format(name, roc_auc_score(gt[:, j], predict[:, j]))
    print 'Mean_AUC:  {}'.format(np.mean(roc_array))
    return total_loss / (i+1)

# %%
save_model_path = '/data1/pengchengtao/Chest X-ray disease/wsss_model/DenseNet_baseline_official_split/'

# %%
step = 0
lossMIN = 100000
for epoch in range(0, num_epochs):
    print 'epoch:' + str(epoch) #+ '  lr:' + str(scheduler.get_lr()[0])
    net.train()
    total_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        inputs, labels, _ = data
        inputs, labels = to_var(inputs), to_var(labels)
        
        optimizer.zero_grad()
        outputs = net(inputs)
        labels = Variable(labels.data.type(torch.FloatTensor)).cuda()
        loss = criterion(outputs.view(-1, 1), labels.view(-1, 1))
        
        loss.backward()
        optimizer.step()
        
        total_loss += loss.data[0]
        
        step += 1
        if (i+1) % 1600 == 0:
            print ('Epoch [%d/%d], Iter [%d/%d], Loss: %.6f' 
                       %(epoch+1, num_epochs, i+1, len(X_train) / batch_size, total_loss / (i+1)))
    torch.save(net, os.path.join(save_model_path, 'Densenet121_epoch_{}_finish.pkl'.format(epoch)))        
    lossVal = eval(net, valloader, step)
    scheduler.step(lossVal)
    if lossVal < lossMIN:
        lossMIN = lossVal           
        torch.save(net, os.path.join(save_model_path, 'Best_Densenet121_epoch_{}.pkl'.format(epoch)))
# Out:
# epoch:0
# Epoch [1/50], Iter [1600/3163], Loss: 0.155220
# /usr/local/lib/python2.7/dist-packages/torch/serialization.py:147: UserWarning: Couldn't retrieve source code for container of type DenseNetChest. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
#
# AUC: Edema:0.839877917722
# AUC: Emphysema:0.896776181298
# AUC: Fibrosis:0.817534617295
# AUC: Pleural_Thickening:0.773371302864
# AUC: Hernia:0.923100380152
# Mean_AUC:  0.806865775096
# epoch:10
# Epoch [11/50], Iter [1600/3163], Loss: 0.124838
# Total val loss:0.202477837163
# AUC: Atelectasis:0.764292529325
# AUC: Cardiomegaly:0.880428273563
# AUC: Effusion:0.82723096971
# AUC: Infiltration:0.68320932681
# AUC: Mass:0.818477131002
# AUC: Nodule:0.760991846984
# AUC: Pneumonia:0.706466260198
# AUC: Pneumothorax:0.86479452224
# AUC: Consolidation:0.745520829822
# AUC: Edema:0.844431595472
# AUC: Emphysema:0.901752493738
# AUC: Fibrosis:0.814446733153
# AUC: Pleural_Thickening:0.782924383767
# AUC: Hernia:0.92025744578
# Mean_AUC:  0.808230310112
# epoch:11
# Epoch [12/50], Iter [1600/3163], Loss: 0.123606
# Total val loss:0.209559356171
# AUC: Atelectasis:0.772691558791
# AUC: Cardiomegaly:0.859028745283
# AUC: Effusion:0.821981854789
# AUC: Infiltration:0.691721257091
# AUC: Mass:0.807097290275
# AUC: Nodule:0.750474880873
# AUC: Pneumonia:0.712349440611
# AUC: Pneumothorax:0.849599005026
# AUC: Consolidation:0.737320635741
# AUC: Edema:0.838760181283
# AUC: Emphysema:0.899106440987
# AUC: Fibrosis:0.820239862184
# AUC: Pleural_Thickening:0.766721572289
# AUC: Hernia:0.902400791299
# Mean_AUC:  0.802106679752
# epoch:12
# Epoch [13/50], Iter [1600/3163], Loss: 0.123507
# Total val loss:0.211876084282
# AUC: Atelectasis:0.762493088205
# AUC: Cardiomegaly:0.882248073685
# AUC: Effusion:0.826400895264
# AUC: Infiltration:0.687319391344
# AUC: Mass:0.81969620046
# AUC: Nodule:0.759174529859
# AUC: Pneumonia:0.721953293895
# AUC: Pneumothorax:0.838685597538
# AUC: Consolidation:0.752091600779
# AUC: Edema:0.845259813743
# AUC: Emphysema:0.876561616762
# AUC: Fibrosis:0.81574403371
# AUC: Pleural_Thickening:0.770722301597
# AUC: Hernia:0.929172326402
# Mean_AUC:  0.806251625946
# epoch:13
# Epoch [14/50], Iter [1600/3163], Loss: 0.122188
# Total val loss:0.207777711475
# AUC: Atelectasis:0.767251057132
# AUC: Cardiomegaly:0.871439477763
# AUC: Effusion:0.823115561366
# AUC: Infiltration:0.694014175848
# AUC: Mass:0.807995414993
# AUC: Nodule:0.752730152187
# AUC: Pneumonia:0.70902415534
# AUC: Pneumothorax:0.859297617136
# AUC: Consolidation:0.738330088041
# AUC: Edema:0.846377703552
# AUC: Emphysema:0.908264757169
# AUC: Fibrosis:0.830782359307
# AUC: Pleural_Thickening:0.759935829904
# AUC: Hernia:0.928381938683
# Mean_AUC:  0.806924306316
# epoch:14
# Epoch [15/50], Iter [1600/3163], Loss: 0.121087
# Total val loss:0.209069387708
# AUC: Atelectasis:0.772971057488
# AUC: Cardiomegaly:0.870226347604
# AUC: Hernia:0.926387736683
# Mean_AUC:  0.807970672754
# epoch:19
# Epoch [20/50], Iter [1600/3163], Loss: 0.111122
# Total val loss:0.214360348756
# AUC: Atelectasis:0.772012538071
# AUC: Cardiomegaly:0.876598985261
# AUC: Effusion:0.826875911958
# AUC: Infiltration:0.688973147083
# AUC: Mass:0.816668035621
# AUC: Nodule:0.761825913261
# AUC: Pneumonia:0.708891184224
# AUC: Pneumothorax:0.8412929301
# AUC: Consolidation:0.741110741578
# AUC: Edema:0.839220093183
# AUC: Emphysema:0.895649967838
# AUC: Fibrosis:0.822281335784
# AUC: Pleural_Thickening:0.770379490299
# AUC: Hernia:0.925873118613
# Mean_AUC:  0.806260956634
# epoch:20
# Epoch [21/50], Iter [1600/3163], Loss: 0.109026
# Total val loss:0.214946014189
# AUC: Atelectasis:0.76982657757
# AUC: Cardiomegaly:0.873301517661
# AUC: Effusion:0.825068801956
# AUC: Infiltration:0.688282588526
# AUC: Mass:0.816345675548
# AUC: Nodule:0.760921591833
# AUC: Pneumonia:0.710523822013
# AUC: Pneumothorax:0.840274751983
# AUC: Consolidation:0.740322302813
# AUC: Edema:0.838116203837
# AUC: Emphysema:0.897263919622
# AUC: Fibrosis:0.820797283883
# AUC: Pleural_Thickening:0.766049080388
# AUC: Hernia:0.923026993518
# Mean_AUC:  0.805008650797
# epoch:21
# Epoch [22/50], Iter [1600/3163], Loss: 0.107577
# Total val loss:0.216203404852
# AUC: Atelectasis:0.771472870404
# AUC: Cardiomegaly:0.872949449611
# AUC: Effusion:0.823826645812
# AUC: Infiltration:0.688395250607
# AUC: Mass:0.81470757158
# AUC: Nodule:0.759049851703
# AUC: Pneumonia:0.706745873704
# AUC: Pneumothorax:0.835725309545
# AUC: Consolidation:0.736404586248
# AUC: Edema:0.836498350728
# AUC: Emphysema:0.892679683452
# AUC: Fibrosis:0.823496315909
# AUC: Pleural_Thickening:0.764443468408
# AUC: Hernia:0.923564402469
# Mean_AUC:  0.803568545013
# epoch:22
# Epoch [23/50], Iter [1600/3163], Loss: 0.107089
# Total val loss:0.218810586817
# AUC: Atelectasis:0.768774955692
# AUC: Cardiomegaly:0.869580584395
# AUC: Effusion:0.824231575806
# AUC: Infiltration:0.685180953113
# AUC: Mass:0.810725376373
# AUC: Nodule:0.759593426359
# AUC: Pneumonia:0.701679911612
# AUC: Pneumothorax:0.836000308618
# AUC: Consolidation:0.733796165492
# AUC: Edema:0.83691667753
# AUC: Emphysema:0.893571427798
# AUC: Fibrosis:0.819599297764
# AUC: Pleural_Thickening:0.76242474046
# AUC: Hernia:0.918775126945
# Mean_AUC:  0.801489323426
# epoch:23
# Epoch [24/50], Iter [1600/3163], Loss: 0.105665
# Total val loss:0.21848972948
# AUC: Atelectasis:0.768680199717
# AUC: Cardiomegaly:0.869794414914
# AUC: Effusion:0.822563624122
# AUC: Infiltration:0.687973497317
# AUC: Mass:0.811826781285
# AUC: Nodule:0.759045456741
# AUC: Pneumonia:0.701763989939
# AUC: Pneumothorax:0.834380995994
# AUC: Consolidation:0.733934943318
# AUC: Edema:0.836791703138
# AUC: Emphysema:0.89423503196
# AUC: Fibrosis:0.820237715092
# AUC: Pleural_Thickening:0.761778259499
# AUC: Hernia:0.921332719499
# Mean_AUC:  0.801738523752
# epoch:24
# Epoch [25/50], Iter [1600/3163], Loss: 0.105722
# Total val loss:0.218097112078
# AUC: Atelectasis:0.768137846795
# AUC: Cardiomegaly:0.870672678051
# AUC: Effusion:0.821725613592
# AUC: Infiltration:0.686184213708
# AUC: Mass:0.812443302721
# AUC: Nodule:0.758167235223
# AUC: Pneumonia:0.701147415536
# AUC: Pneumothorax:0.832366665213
# AUC: Consolidation:0.734355887279
# AUC: Edema:0.835030361722
# AUC: Emphysema:0.890977966774
# AUC: Fibrosis:0.81958202966
# AUC: Pleural_Thickening:0.760937286839
# AUC: Hernia:0.921523707073
# Mean_AUC:  0.800946586442
# epoch:25
# Epoch [26/50], Iter [1600/3163], Loss: 0.105126
# Total val loss:0.219109973472
# AUC: Atelectasis:0.767851781867
# AUC: Cardiomegaly:0.868732642361
# AUC: Effusion:0.821373452407
# AUC: Infiltration:0.684125259913
# AUC: Mass:0.812303676526
# AUC: Nodule:0.758166734043
# AUC: Pneumonia:0.700993110038
# AUC: Pneumothorax:0.831893919789
# AUC: Consolidation:0.733795887473
# AUC: Edema:0.834075153342
# AUC: Emphysema:0.891969573791
# AUC: Fibrosis:0.819810946242
# AUC: Pleural_Thickening:0.76103170619
# AUC: Hernia:0.920136654116
# Mean_AUC:  0.800447178436
# epoch:26
# Epoch [27/50], Iter [1600/3163], Loss: 0.104937
# Total val loss:0.218854755619
# AUC: Atelectasis:0.767096774617
# AUC: Cardiomegaly:0.869328900172
# AUC: Effusion:0.821073921612
# AUC: Infiltration:0.682889432503
# AUC: Mass:0.810797522371
# AUC: Nodule:0.7574377485
# AUC: Pneumonia:0.701069021579
# AUC: Pneumothorax:0.834638870523
# AUC: Consolidation:0.7348712882
# AUC: Edema:0.833984402302
# AUC: Emphysema:0.892667529666
# AUC: Fibrosis:0.818643521926
# AUC: Pleural_Thickening:0.760325278422
# AUC: Hernia:0.9186962705
# Mean_AUC:  0.800251463064
# epoch:27
# Epoch [28/50], Iter [1600/3163], Loss: 0.104743
# Total val loss:0.219015655378
# AUC: Atelectasis:0.766704549925
# AUC: Cardiomegaly:0.867670354921
# AUC: Effusion:0.820902665216
# AUC: Infiltration:0.685440853067
# AUC: Mass:0.81100274565
# AUC: Nodule:0.757275674608
# AUC: Pneumonia:0.702640498411
# AUC: Pneumothorax:0.83238420703
# AUC: Consolidation:0.73398759317
# AUC: Edema:0.833563358665
# AUC: Emphysema:0.891666886655
# AUC: Fibrosis:0.819473395928
# AUC: Pleural_Thickening:0.760671363448
# AUC: Hernia:0.91870766594
# Mean_AUC:  0.800149415188
# epoch:28

# %%
# for epoch in range(0, 20):
#     step = 0
#     print 'epoch:{}'.format(epoch)
#     net = torch.load('DenseNet121_Pretrained/Densenet121_epoch_{}_finish.pkl'.format(epoch)).cuda()
#     _ = eval(net, testloader, step)
# Out:
# epoch:0
# Total val loss:0.156296544592
# AUC: Atelectasis:0.78840646142
# AUC: Cardiomegaly:0.896680831643
# AUC: Effusion:0.876840768924
# AUC: Infiltration:0.689787365149
# AUC: Mass:0.801242183907
# AUC: Nodule:0.728293130364
# AUC: Pneumonia:0.736331943074
# AUC: Pneumothorax:0.851060953683
# AUC: Consolidation:0.795798639311
# AUC: Edema:0.881853718719
# AUC: Emphysema:0.885719026148
# AUC: Fibrosis:0.791598985794
# AUC: Pleural_Thickening:0.740665481012
# AUC: Hernia:0.860131940767
# Mean_AUC:  0.808886530708
# epoch:1
# Total val loss:0.152919179747
# AUC: Atelectasis:0.794917208773
# AUC: Cardiomegaly:0.904709119449
# AUC: Effusion:0.880308434764
# AUC: Infiltration:0.691657697556
# AUC: Mass:0.832820630757
# AUC: Nodule:0.761667559593
# AUC: Pneumonia:0.760900201146
# AUC: Pneumothorax:0.861708500949
# AUC: Consolidation:0.800097647336
# AUC: Edema:0.882187390728
# AUC: Emphysema:0.901031434185
# AUC: Fibrosis:0.82479365313
# AUC: Pleural_Thickening:0.768298630771
# AUC: Hernia:0.915068979671
# Mean_AUC:  0.827154792058
# epoch:2
# Total val loss:0.152252069789
# AUC: Atelectasis:0.804936285216
# AUC: Cardiomegaly:0.904489575681
# AUC: Effusion:0.880276264473
# AUC: Infiltration:0.698273983429
# AUC: Mass:0.824358241239
# AUC: Nodule:0.755096068534
# AUC: Pneumonia:0.749760717527
# AUC: Pneumothorax:0.867107080069
# AUC: Consolidation:0.801755764205
# AUC: Edema:0.887760136614
# AUC: Emphysema:0.901139460519
# AUC: Fibrosis:0.814017281245
# AUC: Pleural_Thickening:0.77034414248
# AUC: Hernia:0.905807180181
# Mean_AUC:  0.826080155815
# epoch:3
# Total val loss:0.150885326258
# AUC: Atelectasis:0.816264490065
# AUC: Cardiomegaly:0.906677307305
# AUC: Effusion:0.880625312592
# AUC: Infiltration:0.693543785117
# AUC: Mass:0.840595245495
# AUC: Nodule:0.765627126912
# AUC: Pneumonia:0.745809298014
# AUC: Pneumothorax:0.871550041956
# AUC: Consolidation:0.807439857045
# AUC: Edema:0.888651742968
# AUC: Emphysema:0.912618031428
# AUC: Fibrosis:0.818761325516
# AUC: Pleural_Thickening:0.776841823849
# AUC: Hernia:0.9231568381
# Mean_AUC:  0.832011587597
# epoch:4
# Total val loss:0.149745539667
# AUC: Atelectasis:0.813448293733
# AUC: Cardiomegaly:0.90232134508
# AUC: Effusion:0.882071914725
# AUC: Infiltration:0.697077037965
# AUC: Mass:0.835324494777
# AUC: Nodule:0.772009843133
# AUC: Pneumonia:0.761857144826
# AUC: Pneumothorax:0.875479314406
# AUC: Consolidation:0.801812813137
# AUC: Edema:0.890012216497
# AUC: Emphysema:0.91548276794
# AUC: Fibrosis:0.82343371505
# AUC: Pleural_Thickening:0.784331966729
# AUC: Hernia:0.914647892117
# Mean_AUC:  0.833522197151
# epoch:5
# Total val loss:0.149712663196
# AUC: Atelectasis:0.818161087855
# AUC: Cardiomegaly:0.89502481741
# AUC: Effusion:0.878527352017
# AUC: Infiltration:0.706816688683
# AUC: Mass:0.839043214864
# AUC: Nodule:0.770399061558
# AUC: Pneumonia:0.772503818278
# AUC: Pneumothorax:0.874163856433
# AUC: Consolidation:0.810000587762
# AUC: Edema:0.889346741791
# AUC: Emphysema:0.915968415985
# AUC: Fibrosis:0.823179387667
# AUC: Pleural_Thickening:0.78693156668
# AUC: Hernia:0.943004310831
# Mean_AUC:  0.837362207701
# epoch:6
# Total val loss:0.150255885266
# AUC: Atelectasis:0.816917928966
# AUC: Cardiomegaly:0.904057093332
# AUC: Effusion:0.880797751626
# AUC: Infiltration:0.707957650147
# AUC: Mass:0.830927509748
# AUC: Nodule:0.761332881012
# AUC: Pneumonia:0.781071620503
# AUC: Pneumothorax:0.878334851169
# AUC: Consolidation:0.807006625753
# AUC: Edema:0.889348666082
# AUC: Emphysema:0.922003552906
# AUC: Fibrosis:0.820904021201
# AUC: Pleural_Thickening:0.769347505686
# AUC: Hernia:0.954668223415
# Mean_AUC:  0.837476848682
# epoch:7
# Total val loss:0.148864982363
# AUC: Atelectasis:0.818366976754
# AUC: Cardiomegaly:0.904659934411
# AUC: Effusion:0.883311822507
# AUC: Infiltration:0.704626097592
# AUC: Mass:0.843846740342
# AUC: Nodule:0.778933800282
# AUC: Pneumonia:0.771768094503
# AUC: Pneumothorax:0.863747189766
# AUC: Consolidation:0.806788866695
# AUC: Edema:0.891033080207
# AUC: Emphysema:0.912915227062
# AUC: Fibrosis:0.834660354041
# AUC: Pleural_Thickening:0.790121608085
# AUC: Hernia:0.962702914224
# Mean_AUC:  0.840534479034
# epoch:8
# Total val loss:0.150261519467
# AUC: Atelectasis:0.818420103379
# AUC: Cardiomegaly:0.911033466113
# AUC: Effusion:0.87782518721
# AUC: Infiltration:0.709246957196
# AUC: Mass:0.849496289298
# AUC: Nodule:0.777090999981
# AUC: Pneumonia:0.774443402898
# AUC: Pneumothorax:0.870183602242
# AUC: Consolidation:0.807641121785
# AUC: Edema:0.893460325524
# AUC: Emphysema:0.922463616946
# AUC: Fibrosis:0.815053928169
# AUC: Pleural_Thickening:0.766660664306
# AUC: Hernia:0.940379957083
# Mean_AUC:  0.838099973009
# epoch:9
# Total val loss:0.150041585039
# AUC: Atelectasis:0.8146984935
# AUC: Cardiomegaly:0.896419061872
# AUC: Effusion:0.882849850854
# AUC: Infiltration:0.706061779974
# AUC: Mass:0.845782707424
# AUC: Nodule:0.777756043404
# AUC: Pneumonia:0.7695071079
# AUC: Pneumothorax:0.87249395705
# AUC: Consolidation:0.806070269104
# AUC: Edema:0.894376562799
# AUC: Emphysema:0.9288079126
# AUC: Fibrosis:0.831227810499
# AUC: Pleural_Thickening:0.793350733902
# AUC: Hernia:0.932053907714
# Mean_AUC:  0.839389728471
# epoch:10
# Total val loss:0.149663636861
# AUC: Atelectasis:0.819155410553
# AUC: Cardiomegaly:0.902999949203
# AUC: Effusion:0.879840115775
# AUC: Infiltration:0.707781672974
# AUC: Mass:0.851730459249
# AUC: Nodule:0.776441471812
# AUC: Pneumonia:0.762798260482
# AUC: Pneumothorax:0.875555206212
# AUC: Consolidation:0.81051008703
# AUC: Edema:0.892157525736
# AUC: Emphysema:0.924091449691
# AUC: Fibrosis:0.835514140577
# AUC: Pleural_Thickening:0.789713811696
# AUC: Hernia:0.967798498972
# Mean_AUC:  0.842577718569
# epoch:11
# Total val loss:0.148798982241
# AUC: Atelectasis:0.821994401986
# AUC: Cardiomegaly:0.911981231524
# AUC: Effusion:0.884455062578
# AUC: Infiltration:0.702980861367
# AUC: Mass:0.849779139681
# AUC: Nodule:0.780211145917
# AUC: Pneumonia:0.756915077254
# AUC: Pneumothorax:0.876721031702
# AUC: Consolidation:0.807258589842
# AUC: Edema:0.892766261356
# AUC: Emphysema:0.917937981145
# AUC: Fibrosis:0.84179697816
# AUC: Pleural_Thickening:0.78914591049
# AUC: Hernia:0.924076637935
# Mean_AUC:  0.839858593638
# epoch:12
# Total val loss:0.150879707853
# AUC: Atelectasis:0.819999944251
# AUC: Cardiomegaly:0.907793701516
# AUC: Effusion:0.882232120376
# AUC: Infiltration:0.701520272798
# AUC: Mass:0.842247222671
# AUC: Nodule:0.77735081835
# AUC: Pneumonia:0.750276245563
# AUC: Pneumothorax:0.86311746847
# AUC: Consolidation:0.801447894595
# AUC: Edema:0.891726594577
# AUC: Emphysema:0.91419563708
# AUC: Fibrosis:0.831055275904
# AUC: Pleural_Thickening:0.785854594939
# AUC: Hernia:0.929942089828
# Mean_AUC:  0.83562570578
# epoch:13
# Total val loss:0.151820783196
# AUC: Atelectasis:0.813151740625
# AUC: Cardiomegaly:0.891651690982
# AUC: Effusion:0.87927483385
# AUC: Infiltration:0.704740626233
# AUC: Mass:0.842688632531
# AUC: Nodule:0.77750865144
# AUC: Pneumonia:0.766080527025
# AUC: Pneumothorax:0.871032609556
# AUC: Consolidation:0.800982234208
# AUC: Edema:0.893332497641
# AUC: Emphysema:0.920765977055
# AUC: Fibrosis:0.835605257868
# AUC: Pleural_Thickening:0.772776228842
# AUC: Hernia:0.917030864867
# Mean_AUC:  0.834758740909
# epoch:14
# Total val loss:0.152617085135
# AUC: Atelectasis:0.820296342501
# AUC: Cardiomegaly:0.90683323685
# AUC: Effusion:0.880715734452
# AUC: Infiltration:0.703619840977
# AUC: Mass:0.83883890871
# AUC: Nodule:0.78021957812
# AUC: Pneumonia:0.768653698115
# AUC: Pneumothorax:0.868724083206
# AUC: Consolidation:0.804107274958
# AUC: Edema:0.896509611557
# AUC: Emphysema:0.921086068358
# AUC: Fibrosis:0.826824579941
# AUC: Pleural_Thickening:0.784637892503
# AUC: Hernia:0.945496808879
# Mean_AUC:  0.839040261366
# epoch:15
# Total val loss:0.15065573948
# AUC: Atelectasis:0.815626299517
# AUC: Cardiomegaly:0.906700346819
# AUC: Effusion:0.8836522722
# AUC: Infiltration:0.70581238859
# AUC: Mass:0.844325568001
# AUC: Nodule:0.77804114063
# AUC: Pneumonia:0.755743896621
# AUC: Pneumothorax:0.865809067746
# AUC: Consolidation:0.801979824189
# AUC: Edema:0.888929775485
# AUC: Emphysema:0.925439247352
# AUC: Fibrosis:0.830294046011
# AUC: Pleural_Thickening:0.790668884024
# AUC: Hernia:0.924521119242
# Mean_AUC:  0.836967419745
# epoch:16
# Total val loss:0.152310072364
# AUC: Atelectasis:0.817265420039
# AUC: Cardiomegaly:0.900798299511
# AUC: Effusion:0.87752853229
# AUC: Infiltration:0.705988736472
# AUC: Mass:0.841703255721
# AUC: Nodule:0.77462405688
# AUC: Pneumonia:0.753584581792
# AUC: Pneumothorax:0.860755615649
# AUC: Consolidation:0.800614250351
# AUC: Edema:0.888349629327
# AUC: Emphysema:0.925968401648
# AUC: Fibrosis:0.823835294483
# AUC: Pleural_Thickening:0.782532514149
# AUC: Hernia:0.942279104487
# Mean_AUC:  0.835416263771
# epoch:17
# Total val loss:0.152009476042
# AUC: Atelectasis:0.815051445899
# AUC: Cardiomegaly:0.900811273981
# AUC: Effusion:0.883824831169
# AUC: Infiltration:0.709433987004
# AUC: Mass:0.856905842232
# AUC: Nodule:0.782621495621
# AUC: Pneumonia:0.760149673514
# AUC: Pneumothorax:0.865178055772
# AUC: Consolidation:0.809023530531
# AUC: Edema:0.88972588204
# AUC: Emphysema:0.915394097631
# AUC: Fibrosis:0.82093537406
# AUC: Pleural_Thickening:0.782765293997
# AUC: Hernia:0.939995023511
# Mean_AUC:  0.837986843355
# epoch:18
# Total val loss:0.151323121555
# AUC: Atelectasis:0.817550813046
# AUC: Cardiomegaly:0.90166350011
# AUC: Effusion:0.884155621472
# AUC: Infiltration:0.710207561623
# AUC: Mass:0.850515893241
# AUC: Nodule:0.782351327832
# AUC: Pneumonia:0.756180936282
# AUC: Pneumothorax:0.869932759171
# AUC: Consolidation:0.802514624475
# AUC: Edema:0.89237821439
# AUC: Emphysema:0.930569310879
# AUC: Fibrosis:0.825200739652
# AUC: Pleural_Thickening:0.78607707785
# AUC: Hernia:0.943386054346
# Mean_AUC:  0.839477459598
# epoch:19
# Total val loss:0.153327575553
# AUC: Atelectasis:0.815356536846
# AUC: Cardiomegaly:0.902514232208
# AUC: Effusion:0.881981372931
# AUC: Infiltration:0.708223716593
# AUC: Mass:0.845095222704
# AUC: Nodule:0.779936486871
# AUC: Pneumonia:0.75321262324
# AUC: Pneumothorax:0.869269394229
# AUC: Consolidation:0.801368707272
# AUC: Edema:0.88884175293
# AUC: Emphysema:0.929834409206
# AUC: Fibrosis:0.82178834705
# AUC: Pleural_Thickening:0.779737429355
# AUC: Hernia:0.93947823424
# Mean_AUC:  0.836902747548
